# %%
# calls Figure 5.7 to be shown for the solution to Example 5.6

from pathlib import Path


path = Path('.')
fig = path.absolute().parents[0] / 'Figure' / 'Figure_05_07.ipynb'
fig = str(fig.absolute())
# %run $fig
