# %%
#calls Figure 5.7 & 5.8 to be shown for the solution to Example 5.7

from pathlib import Path


path = Path('.')
fig = path.absolute().parents[0] / 'Figure'
fig_paths = [(fig / f) for f in ['Figure_05_07.ipynb', 'Figure_05_08.ipynb']]
figures = [str(f.absolute()) for f in fig_paths]
for f in figures:
    # %run $f
