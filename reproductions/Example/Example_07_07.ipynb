# %%
#calls Figure 7.7 to be shown for the solution to Example 7.7

from pathlib import Path


path = Path('.')
fig = path.absolute().parents[0] / 'Figure' / 'Figure_07_07.ipynb'
fig = str(fig.absolute())
# %run $fig
